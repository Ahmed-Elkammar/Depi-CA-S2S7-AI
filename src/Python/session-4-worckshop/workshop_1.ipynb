# %%
def is_prime(num : int)-> bool :
    for i in range (2,num):
        if num %i == 0:
            return False

    return True

    ''' 
    

    '''

# %%
is_prime(7)
# Out:
# True

# %%
def fact(num : int) -> int:
    if num == 0:
        return 1
    return num * fact(num-1)

# %%
fact(10)
# Out:
# 3628800

# %%
def common_divisors ( num1: int, num2 :int)-> list[int]:
    limit = min(num1,num2)
    divisors = []
    for i in range (1 , limit +1):
        if num1 % i ==0 and num2 %i ==0 :
            divisors.append(i)
    return divisors

# %%
common_divisors(20,10)
# Out:
# [1, 2, 5, 10]

# %%
s = "hi there"
lsst = s.split()
new_list = lsst[::-1]
print(new_list)

# %%
def reverse_word (word: str)->list:
    lsst = word.split()
    new_list = lsst[::-1]
    return new_list
reverse_word("hi world")
# Out:
# ['world', 'hi']

# %%
import random
char = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
password = ""
for _ in range (3):
#_in for loop means ignore
    password +=random.choice(char)
print(password)
# Out:
# yRF

# %%
def random_pass (lenth: int)->str:
    char = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    password = ""
    
    for _ in range (lenth):
    #_in for loop means ignore
        password +=random.choice(char)
    return  password

# %%
random_pass(8)
# Out:
# '%APn$&8I'

# %%
import string
import secrets
def random_pass (length: int)->str:
    if length <= 0:
        raise ValueError("password lenght must be greater than 0")
    char = (
        string.ascii_letters +
        string.digits +
        string.punctuation

    )
    
    return "".join(secrets.choice(char)for _ in range(length))

# %%
random_pass(10)
# Out:
# 'zhj*W5wpy{'

# %%
numbers = [1,2,3,4,5]
squres = []
for num in numbers :
    squres.append(num**2)
squres
# Out:
# [1, 4, 9, 16, 25]

# %%
squres = [num **2 for num in numbers if num % 2 == 0]
squres
# Out:
# [4, 16]

# %%
words = [ "welcom", "ali","hi","No","hi","ali"]
unique_word = set(words)
counts =

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
def count_word (words : list):
    unique_words = set(words)
    counted= {}
    for word in unique_words:
        counted[word] = words.count(word)
    return counted
print(count_word(words))
# Out:
# {'No': 3, 'Hi': 2, 'Welcome': 1, 'Ali': 4}

# %%
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}
def get_response ( user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return  random.choice(responses["default"])


def main():
    print( "chatbot : hhi how can i help you")
    while True:
        user_input = input("user:  ").lower()
        responses = get_response( user_input )
        print("chatbot",responses )
        if user_input ==" goodbye":
            break

# %%
try :
    50/0
except ZeroDivisionError:
    print("division by zero not allowed")
    
#code
# Out:
# division by zero not allowed

# %%
num1 = 5
num2 = 5
res = num1/num2
type (res)
res
# Out:
# 1.0
