# %%
number = 29
is_prime = True
 
if number <= 1:
    is_prime = False
else:
    for i in range(2, int(number ** 0.5) + 1):
        if number % i == 0:
            is_prime = False
            break
 
if is_prime:
    print(f"The number {number} is prime.")
else:
    print(f"The number {number} is not prime.")
# Out:
# The number 29 is prime.

# %%
def is_prime (num : int):
    number = num
is_prime = True
 
if number <= 1:
    is_prime = False
else:
    for i in range(2, int(number ** 0.5) + 1):
        if number % i == 0:
            is_prime = False
            break
 
if is_prime:
    print (f"The number {number} is prime.")
else:
    print (f"The number {number} is not prime.")
''' this function takes integer number and prints if it is prim number or not 
    args: num: the number you want to check
    retunes: null
'''
# Out:
#   Cell In[4], line 13
#     if is_prime:    return (f"The number {number} is prime.")
#                     ^
# SyntaxError: 'return' outside function
