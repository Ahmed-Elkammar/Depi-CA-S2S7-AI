# %%
class Student():
    """
    class info
    
    
    """

    name = "ahmed"
    age = 19

    def std_info(self):
        print(self)

# %%
s1 = Student()
s1.age = 30
print(s1.name)
print(s1.age)
print(s1.std_info())

s2 = Student()
s2.age = 30
print(s2.name)
print(s2.age)
print(s2.std_info())
# Out:
# ahmed
# 30
# ...
# None
# ahmed
# 30
# ...
# None

# %%
class Student:
    def __init__(self, name = "test",age = 5 )-> None:
        self.name = name
        self.age = age
        self.grade = 0 

    def std_info(self)  :  
        return f"my name is {self.name},and age is {self.age}"

# %%
s1 = Student( 10 ,"ok")

s1.std_info()
# Out:
# 'my name is 10,and age is ok'

# %%
def add1(x,y):
    return x + y

class calc:
    def __init__(self,x,y):
        self.x = x
        self.y = y

    def add(self):
        return self.x +self.y

# %%
s = calc

# %%
from abc import ABC , abstractmethod

class Animal (ABC):
    @abstractmethod
    def move (self):
        pass

class Bird (Animal):
    def move(self):
        print ("move from Bird")

class Cat(Animal) :
    def move(self):
        print("move from Cat")


a = Bird()

a.move()

b = Cat()
b.move()
# Out:
# move from Bird
# move from Cat

# %%
class Rectangle:
    length = 5
    __width = 12
    """name mangling"""
    

    def area(self):
        return self.length * self.__width

    '''_length act as protected (name convension)'''

r = Rectangle()
print(r.length)
print(r._Rectangle__width)
print(r.area())
# Out:
# 5
# 12
# 60

# %%
class Rectangle:

    def __init__(self , length , width):
        self.__length = length
        self.width = width
    @property
    def length(self):
        return self.__length
    @length.setter
    def length (self, value):
        if value <= 0 :
            raise ValueError("length must be positive")
        self.__length = value

# %%
r = Rectangle(10,34)
r.length = 120
r.length
# Out:
# 120

# %%
class parent:
    def __init__(self):
        self.__value = 10


class child(parent):

    def __init__(self):
        super().__init__()
        self.__value = 20

# %%
c = child()
print (c.__dict__)
# Out:
# {'_parent__value': 10, '_child__value': 20}

# %%
class Shape:
    def calculate_area(self):
        pass


class Circle (Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area (self):
        return 3.14 * (self.radius)**2

class Square (Shape):
    def __init__(self,side):
        self.side = side

    def calculate_area(self):
        return self.side**2

x= Circle(4)
y = Square(5)
print(x.calculate_area())
print(y.calculate_area())
# Out:
# 50.24
# 25

# %%
class Model:

    def fit(self , x ,y ):
        raise NotImplementedError
    def predict (self, x):
        raise NotImplementedError

class LinearRegression(Model):
    def fit (self , x , y):

        print("fitting Linear regression") 

    def predict(self, x):
        print ("predicting with linear regression")       

class DicisionTree(Model):
    def fit(self, x, y):
        print("fitting Decision Tree ")
   
    def predict(self, x):
        print("predicting with Decision Tree ")


models = [LinearRegression(),DicisionTree()]
for model in models :
    model.fit(None, None)
    model.predict(None)
# Out:
# fitting Linear regression
# predicting with linear regression
# fitting Decision Tree
# predicting with Decision Tree

# %%
class calc:
    def add (self, a):
        return a
    def add (self , a , b):
        return a + b

# %%
c1 = calc()
c1.add(20 , 10)
# Out:
# 30

# %%
class point :
    def __init__(self) ->:

    def __add__(self, other):
        pass
