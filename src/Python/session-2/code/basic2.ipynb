# %%
list_one =[1,2,3,4,"Depi","Learning",True,[1,2,3,4,5,"True",["ML","AI"]]]
list_one[5] = "Deep Learning"
list_one[7][6][0] = "Machine Learning"
list_one[7][6][1]
# Out:
# 'AI'

# %%
list("Ahmed")

print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
list_1 = ["Ml","m","neo"]
x = list_1.append("AI")
list_1.append("AI")
print(list_1) 
print(x)
# Out:
# ['Ml', 'm', 'neo', 'AI', 'AI']
# None

# %%
list_1.insert(1,"Hello")
print(list_1)
list_2 = ["Ml","m","neo"]
list_2.insert(2,"Hello")
print(list_2)
# Out:
# ['Ml', 'Hello', 'Hello', 'Hello', 'm', 'Hello', 'Hello', 'neo', 'AI', 'AI']
# ['Ml', 'm', 'Hello', 'neo']

# %%
list_1 = ["Ml","m","neo"]
list_2 = ["Hello","World"]
list_1.extend(list_2)
print(list_1)
# Out:
# ['Ml', 'm', 'neo', 'Hello', 'World']

# %%
list_1 = ["Ml","m","neo"]
list_1.remove("m")
print(list_1)
# Out:
# ['Ml', 'neo']

# %%
list_1 = ["Ml","m","neo","Hello","World"]
x = list_1.pop(2)
print(list_1)
print(x)
# Out:
# ['Ml', 'm', 'Hello', 'World']
# neo

# %%
list = ["hei","helloe","Now"]
New_list = ["welcome"]
N_list = list.pop(1)
New_list.append(N_list)
print(New_list)
# Out:
# ['welcome', 'helloe']

# %%
list = ["hei","helloe","Now"]
del list[:]
print(list)
list.clear()
print(list)
# Out:
# []
# []

# %%
name = input("Enter your name: ")
id = input("Enter your id: ")

# %%
input_list = ["amit","learning","python","machine learning","data science","deep learning"]
rem_iteme = input("Enter the item you want to remove: ")
input_list.remove(rem_iteme)
print(input_list)
# Out:
# ['amit', 'python', 'machine learning', 'data science', 'deep learning']

# %%
lest = [200,2,5,12]
lest.sort()
lest.sort(reverse=True)
lest
# Out:
# [200, 12, 5, 2]

# %%
lsit = [1,2,3,4,5,6,7,8,9]
lsit.reverse()
lsit
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
tup = ("amit","learning","python","machine learning","data science","deep learning")
tup
# Out:
# ('amit',
#  'learning',
#  'python',
#  'machine learning',
#  'data science',
#  'deep learning')

# %%
name = ["ahmed","ali","hassan"]

# %%
set_1 = {"ahmed","ali","hassan"}
print(set_1)
# Out:
# {'ali', 'ahmed', 'hassan'}

# %%
set = {3,4,1,4,5,6,7,4}
set.add(30)
set
# Out:
# {1, 3, 4, 5, 6, 7, 30}

# %%
dict1 = {"name":"ahmed","age":20,"id":1234}
dict1["name"] = "ali"
dict1   
del dict

# %%
list_1 = [('abs', 1), ('bcd', 2), ('cde', 3 )]
new_dict1 = dict(list_1)
print(new_dict1)
# Out:
# {'abs': 1, 'bcd': 2, 'cde': 3}

# %%
chat = {"hi":"hello","how are you":"I am fine","what is your name":"My name is Depi"}
ask = input("Ask me something: ").lower()
print(chat.get(ask,"I don't understand your question."))
# Out:
# I don't understand your question.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
print("sum of two numbers is: ",num1+num2)
print("subtraction of two numbers is: ",num1-num2)
print("multiplication of two numbers is: ",num1*num2)
print("division of two numbers is: ",num1/num2)

# %%
a =
