# %%
age = 30
print ("hi my age is", age)
# Out:
# hi my age is 30

# %%
x = 10
print(x+1.5)
(id(x))
# Out:
# 11.5
# 140730267880152

# %%
#this is a comment

x='''  
this a multi line comment 
'''
print("try comment.")
print(x)
# Out:
# try comment.
#
# this a multi line comment

# %%
x = 32
print(type(x))
type(x)
# Out:
# <class 'int'>
# int

# %%
name = "Ahmed"
age = 19
print("My name is {} and I am {} years old.".format(  name, age))
# Out:
# My name is Ahmed and I am 19 years old.

# %%
print(f"I'm {age} my age is {name}")
# Out:
# I'm 19 my age is Ahmed

# %%
name = "Ahmed Yehia Elkammar"
age = 19
course_name = "python"
output =f"my name is {name} and my age is {age} and I am in {course_name} course"
print(output)
# Out:
# my name is Ahmed Yehia Elkammar and my age is 19 and I am in python course

# %%
x = [1, 2, 3, 4, 5]
x[4] = 22.5
print(x)
# Out:
# [1, 2, 3, 4, 22.5]

# %%
a ={}

# %%
name = "AMIT study"
name[2 : 7: 2]
name.lower()
name.upper()
name.replace("study", "studies")
name.capitalize("study")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 6
#       2 name[2 : 7: 2]
#       3 name.lower()
#       4 name.upper()
#       5 name.replace("study", "studies")
# ----> 6 name.capitalize("study")
#
# TypeError: str.capitalize() takes no arguments (1 given)

# %%
name.capitalize()
name.split()
name.capitalize()
# Out:
# 'Amit study'

# %%
# Out:
# mocleW EPGTQ
# ['mocleW', 'EPGTQ']
# Welcom
# PGTQ
# Welcom PGTQ
